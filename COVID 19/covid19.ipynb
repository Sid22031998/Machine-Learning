# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import glob, os

# %% [markdown]
# ## Overall Analysis

# %%
data = pd.concat(map(pd.read_csv, glob.glob(os.path.join('', "dataset\*.csv"))))

# %%
data.fillna(0)
# Out:
#       Active Admin2        Combined_Key  Confirmed  Country/Region  \
# 0        0.0      0                   0        1.0  Mainland China
# 1        0.0      0                   0       14.0  Mainland China
# 2        0.0      0                   0        6.0  Mainland China
# 3        0.0      0                   0        1.0  Mainland China
# 4        0.0      0                   0        0.0  Mainland China
# ...      ...    ...                 ...        ...             ...
# 3172   266.0      0  West Bank and Gaza      344.0               0
# 3173     1.0      0      Western Sahara        6.0               0
# 3174     3.0      0               Yemen        6.0               0
# 3175    48.0      0              Zambia      106.0               0
# 3176    31.0      0            Zimbabwe       40.0               0
#
#           Country_Region  Deaths  FIPS      Last Update          Last_Update  \
# 0                      0     0.0   0.0  1/22/2020 17:00                    0
# ...

# %%
data.dtypes
# Out:
# Active            float64
# Admin2             object
# Combined_Key       object
# Confirmed         float64
# Country/Region     object
# Country_Region     object
# Deaths            float64
# FIPS              float64
# Last Update        object
# Last_Update        object
# Lat               float64
# Latitude          float64
# Long_             float64
# Longitude         float64
# Province/State     object
# Province_State     object
# Recovered         float64
# dtype: object

# %%
data = data.drop(['Last_Update', 'Lat', 'Latitude', 'Long_', 'Longitude', 'Admin2', 'FIPS'], axis=1)

# %%
data = data.drop(['Combined_Key'], axis=1)

# %%
data = data.drop(['Last Update'], axis=1)

# %%
data = data.fillna(0)

# %%
data.head(10)
# Out:
#    Active  Confirmed  Country/Region Country_Region  Deaths Province/State  \
# 0     0.0        1.0  Mainland China              0     0.0          Anhui
# 1     0.0       14.0  Mainland China              0     0.0        Beijing
# 2     0.0        6.0  Mainland China              0     0.0      Chongqing
# 3     0.0        1.0  Mainland China              0     0.0         Fujian
# 4     0.0        0.0  Mainland China              0     0.0          Gansu
# 5     0.0       26.0  Mainland China              0     0.0      Guangdong
# 6     0.0        2.0  Mainland China              0     0.0        Guangxi
# 7     0.0        1.0  Mainland China              0     0.0        Guizhou
# 8     0.0        4.0  Mainland China              0     0.0         Hainan
# 9     0.0        1.0  Mainland China              0     0.0          Hebei
#
#   Province_State  Recovered
# 0              0        0.0
# 1              0        0.0
# 2              0        0.0
# ...

# %%
data.dtypes
# Out:
# Active            float64
# Confirmed         float64
# Country/Region     object
# Country_Region     object
# Deaths            float64
# Province/State     object
# Province_State     object
# Recovered         float64
# dtype: object

# %%
data[7617:7620]
# Out:
#    Active  Confirmed Country/Region Country_Region  Deaths Province/State  \
# 0     0.0     9654.0              0             US    63.0              0
# 1     0.0     1900.0              0             US     4.0              0
# 2     0.0     1873.0              0             US     0.0              0
#
#   Province_State  Recovered
# 0       New York        0.0
# 1       New York        0.0
# 2       New York        0.0

# %%
data['Country_Region'].unique()
# Out:
# array([0, 'US', 'Canada', 'Australia', 'China', 'Taiwan*', 'Italy',
#        'Spain', 'Germany', 'Iran', 'France', 'Korea, South',
#        'Switzerland', 'United Kingdom', 'Netherlands', 'Austria',
#        'Belgium', 'Norway', 'Sweden', 'Portugal', 'Brazil', 'Denmark',
#        'Malaysia', 'Turkey', 'Czechia', 'Japan', 'Israel', 'Ireland',
#        'Luxembourg', 'Ecuador', 'Pakistan', 'Cruise Ship', 'Poland',
#        'Chile', 'Finland', 'Greece', 'Thailand', 'Iceland', 'Indonesia',
#        'Saudi Arabia', 'Qatar', 'Singapore', 'Romania', 'Slovenia',
#        'India', 'Philippines', 'Russia', 'Peru', 'Bahrain', 'Egypt',
#        'Estonia', 'Panama', 'South Africa', 'Argentina', 'Croatia',
#        'Mexico', 'Lebanon', 'Iraq', 'Colombia', 'Serbia',
#        'Dominican Republic', 'Algeria', 'Armenia', 'Kuwait', 'Bulgaria',
#        'Slovakia', 'San Marino', 'United Arab Emirates', 'Latvia',
#        'Uruguay', 'Costa Rica', 'Hungary', 'Lithuania',
# ...

# %%
plt.figure(figsize=(12,8))
plt.xlim(0, 300000, 50000)
plt.ylim(0, 160000, 40000)
plt.xlabel('Confirmed')
plt.title('Deaths Rate vs Recovery Rate')
plt.scatter(data['Confirmed'], data['Deaths'], color='red', label='Deaths')
plt.scatter(data['Confirmed'], data['Recovered'], color='blue', label='Recovered')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.regplot(data['Confirmed'], data['Active'])

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # As of 30th April 2020

# %%
df = pd.read_csv('dataset/04-30-2020.csv', error_bad_lines = False)
df.head(10)
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-05-01 02:32:28
# 1  22001.0     Acadia       Louisiana             US  2020-05-01 02:32:28
# 2  51001.0   Accomack        Virginia             US  2020-05-01 02:32:28
# 3  16001.0        Ada           Idaho             US  2020-05-01 02:32:28
# 4  19001.0      Adair            Iowa             US  2020-05-01 02:32:28
# 5  21001.0      Adair        Kentucky             US  2020-05-01 02:32:28
# 6  29001.0      Adair        Missouri             US  2020-05-01 02:32:28
# 7  40001.0      Adair        Oklahoma             US  2020-05-01 02:32:28
# 8   8001.0      Adams        Colorado             US  2020-05-01 02:32:28
# 9  16003.0      Adams           Idaho             US  2020-05-01 02:32:28
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707         31       0          0      31
# ...

# %%
df.count()
# Out:
# FIPS              3177
# Province_State    3177
# Country_Region    3177
# Confirmed         3177
# Deaths            3177
# Recovered         3177
# Active            3177
# dtype: int64

# %%
df.dtypes
# Out:
# FIPS              float64
# Admin2             object
# Province_State     object
# Country_Region     object
# Last_Update        object
# Lat               float64
# Long_             float64
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# Combined_Key       object
# dtype: object

# %%
df = df.drop(['Last_Update', 'Lat', 'Long_', 'Admin2', 'Combined_Key'], axis=1)

# %%
df.head()
# Out:
#       FIPS  Province_State Country_Region  Confirmed  Deaths  Recovered  \
# 0  45001.0  South Carolina             US         31       0          0
# 1  22001.0       Louisiana             US        130      10          0
# 2  51001.0        Virginia             US        264       4          0
# 3  16001.0           Idaho             US        671      16          0
# 4  19001.0            Iowa             US          1       0          0
#
#    Active
# 0      31
# 1     120
# 2     260
# 3     655
# 4       1

# %%
df = df.fillna(0)

# %%
df1 = df[:12]
plt.figure(figsize=(14,6))
plt.xlabel(' Province States in US')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases in US')
plt.bar(df1['Province_State'], df1['Active'])
plt.show()

# %%
df2=df[3000:3010]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df2['Country_Region'], df2['Active'])
plt.show()

# %%
df3=df[3050:3060]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df3['Country_Region'], df3['Active'])
plt.show()

# %%
df4=df[3100:3110]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df4['Country_Region'], df4['Active'])
plt.show()

# %%
df5=df[3070:3080]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df5['Country_Region'], df5['Active'])
plt.show()

# %%
df6=df[3120:3130]
plt.figure(figsize=(18,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df6['Country_Region'], df6['Active'])
plt.show()

# %%
df7=df[3150:3160]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df7['Country_Region'], df7['Active'])
plt.show()

# %%
df8=df[3028:3035]
plt.figure(figsize=(14,6))
plt.xlabel('Country')
plt.ylabel('Active Cases')
plt.title('COVID 19 Cases Around the World')
plt.bar(df8['Country_Region'], df8['Active'])
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlim(-10000, 150000)
plt.ylim(-10000, 200000)
plt.xlabel('Confirmed')
plt.title('Active Cases vs Recovery Rate')
plt.scatter(df['Confirmed'], df['Active'], color='red', label='Active')
plt.scatter(df['Confirmed'], df['Recovered'], color='blue', label='Recovered')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.suptitle('Recovery Rate vs Death Rate')
plt.subplot(121)
sns.regplot(df['Active'], df['Recovered'], color='green')
plt.subplot(122)
sns.regplot(df['Active'], df['Deaths'], color='red')

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Situation in INDIA as of 1st May 2020

# %%
india = pd.read_excel('dataset/india.xlsx', error_bad_lines = False)
india.head(10)
# Out:
#    S. No.           Name Of State / UT  Confirmed  Recovered  Death  \
# 0       1  Andaman and Nicobar Islands         33         16      0
# 1       2               Andhra Pradesh       1463        403     33
# 2       3            Arunachal Pradesh          1          1      0
# 3       4                        Assam         42         29      1
# 4       5                        Bihar        426         82      2
# 5       6                   Chandigarh         56         17      0
# 6       7                 Chhattisgarh         40         36      0
# 7       8                        Delhi       3515       1094     59
# 8       9                          Goa          7          7      0
# 9      10                      Gujarat       4395        613    214
#
#         Date            DateTime
# 0 2020-05-01 2020-05-01 18:00:14
# 1 2020-05-01 2020-05-01 18:00:14
# 2 2020-05-01 2020-05-01 18:00:14
# 3 2020-05-01 2020-05-01 18:00:14
# 4 2020-05-01 2020-05-01 18:00:14
# ...

# %%
india.count()
# Out:
# S. No.                32
# Name Of State / UT    32
# Confirmed             32
# Recovered             32
# Death                 32
# Date                  32
# DateTime              32
# dtype: int64

# %%
plt.figure(figsize=(20, 50))
sns.barplot(india['Confirmed'], india['Name Of State / UT'])

# %%
plt.figure(figsize=(20, 50))
sns.barplot(india['Recovered'], india['Name Of State / UT'])

# %%
plt.figure(figsize=(20, 50))
sns.barplot(india['Death'], india['Name Of State / UT'])

# %%
plt.figure(figsize=(20, 8))
plt.suptitle('Recovery Rate vs Death Rate')
plt.subplot(121)
sns.regplot(india['Confirmed'], india['Recovered'], color='green')
plt.subplot(122)
sns.regplot(india['Confirmed'], india['Death'], color='red')
plt.show()
